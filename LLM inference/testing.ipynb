# %%
import pandas as pd

# %%
# load csv in data folder
df = pd.read_csv('data/test_mistral.csv')
for index, row in df.iterrows():
    print(row["answer"])
# Out:
# Most common phobia in chilhood:
# choose only one of the following options:
# 1. Zoophobia
# 2. Nyclophobia
# 3. Xenophobia.
# 4. Claustrophobia
#
# Answer:
# 3
# In a population of 10000 people, the prevalence of a disease is 20%. The sensitivity of a screening test is 95% and specificity is 80%. The positive predictive value of the test will be -
# choose only one of the following options:
# 1. 45.70%
# 2. 54.30%
# 3. 15.30%
# 4. 98.50%
# Answer: 3.
# Which of the following is not a cause of clubfoot in newborns?
# choose only one of the following options:
# 1. CTEV
# 2. Ahogryposis multiplex cngenita
# 3. Polio
# 4. Spina bifida
# Answer:
# 3.
# What is NOT a major criteria for Rheumatic heart disease –
# choose only one of the following options:
# 1. Arthritis
# 2. Carditis
# 3. Subcutaneous nodule
# 4. Raised ASLO titer
#
# Answer: Arth
# When length of a spring is doubled, the effect is:
# choose only one of the following options:
# 1. Doubled
# 2. Four times
# 3. Six times
# 4. Eight times
# Answer: 2.
# Most difficult maxillary tooth to anaesthetize by infiltration is :
# choose only one of the following options:
# 1. 1st molar
# 2. 1st premolar
# 3. Canine
# 4. 3rd molar
#
# Answer: 3
# A morbidly obese diabetic woman was on failed metformin therapy. She has the history of pancreatitis and family history of bladder cancer. Patient does not want to take injections. Which of the following would be suitable to reduce her glucose levels?
# choose only one of the following options:
# 1. Liraglutide
# 2. Sitagliptin
# 3. Canagliflozin
# 4. Pioglitazone
# Answer: 1.
# Patient complaint of loose immediate dentures today morning, and also told that this happened 2-3 days back also. What could be the possible reason
# choose only one of the following options:
# 1. Patient forgot how to insert the denture
# 2. Continuous healing of defect
# 3. Due to shrinkage of resin
# 4. Due to reduction of diameter of defect
# 5. Due to loss of
# Heart of controlled trial?
# choose only one of the following options:
# 1. Blinding
# 2. Experiment
# 3. Randomization
# 4. Intervention
#
# The heart of a controlled
# Bonding agents have hydrophilic and hydrophobic groups. The hydrophobic group binds which structure?
# choose only one of the following options:
# 1. Calcium in enamel
# 2. Hydroxyapatite group in hard tissue
# 3. Resin in restoration
# 4. Collagen in dentin
#
# Answer: 3
# KRI paste composition is:
# choose only one of the following options:
# 1. Iodoform+ZOE
# 2. Iodoform+chlorophenol+menthol
# 3. Iodoform+CaOH
# 4. Iodoform only
#
# Answer: I.
# Universal marker of limbal epithelial stem cells:
# choose only one of the following options:
# 1. Elastin
# 2. Keratin
# 3. Collagen
# 4. ABCG2
#
# Answer: 4
# Supragingival plaque undergoes which of the following changes with time?
# choose only one of the following options:
# 1. Plaque mass decreases
# 2. Plaque microflora becomes more gram positive
# 3. Plaque microflora becomes gram negative
# 4. Plaque microflora becomes predominantly spirochetal
#
# Answer: 2
# An 11-year-old boy complains of spacing between maxillary incisors. The appropriate treatment is with:
# choose only one of the following options:
# 1. Hawley's appliance
# 2. Fixed appliance
# 3. No treatment
# 4. Oral screen
#
# Answer: 2
# Patient's cross-infection with sensor, in digital radiography/RVG is prevented by
# choose only one of the following options:
# 1. Cover with autoclaved cloth with each use
# 2. Wipe with ethyl alcohol in each patient
# 3. Clean with 5.25% sodium hypochlorite in each patient
# 4. Cover with impervious barrier film between patients
#
# Answer
# Major determinant of loading dose of a drug is:-
# choose only one of the following options:
# 1. Half life
# 2. Clearance
# 3. Volume of distribution
# 4. Bioavailability
# Answer: 3.
# A 30 year old male presented with severe dyspnea. His investigations showed mitral stenosis with left atrial enlargement. The histopathology repo from his mitral valve is shown below. What is the likely diagnosis of these patients?
# choose only one of the following options:
# 1. Sarcoidosis
# 2. Fungal granuloma
# 3. Tuberculosis
# 4. Rheumatic hea disease
#
# Answer: 4
# The two roots of auriculotemporal nerve encircles which structure
# choose only one of the following options:
# 1. Superficial temporal vein
# 2. Superficial temporal artery
# 3. Anterior tympanic artery
# 4. Middle meningeal artery
#
# Answer: 1
# Easiest 3rd molar surgical extraction is:
# choose only one of the following options:
# 1. Mesioangular
# 2. Horizontal
# 3. Vertical
# 4. Distoangular
#
# Answer: The easiest
# Which of the following drug is used to counter act the gastric irritation produced by administration of NSAID:
# choose only one of the following options:
# 1. Roxatidine
# 2. Pirenzipine
# 3. Betaxolol
# 4. Misoprostol
# Answer: 4.
# What is the approved dose of misoprostol in emergent management of postpaum hemorrhage?
# choose only one of the following options:
# 1. 200 mcg
# 2. 400 mcg
# 3. 600 mcg
# 4. 1000 mcg
#
# Answer: 8
# Which of the following hematological disease is associated with periodontal disease?
# choose only one of the following options:
# 1. AIDS
# 2. Hypophosphatesia
# 3. Wegener's granulomatosis
# 4. Histocytosis X
#
# Answer:
#
# Hematuria during labour in previous LSCS is sign
# choose only one of the following options:
# 1. Impending rupture of scar
# 2. Urethral trauma
# 3. Prolong labour
# 4. Sepsis
#
# Answer: 1
# Detachment of myosin head from actin is caused by?
# choose only one of the following options:
# 1. Entry of calcium into sarcoplasmic reticulum
# 2. Change in troponin C configuration
# 3. Binding of ATP
# 4. Release of ADP and Pi
#
# Answer: 3
# In mechanical trituration of amalgam, what is adversely affected ?
# choose only one of the following options:
# 1. Hardness of filling
# 2. Tarnish resistance
# 3. Working time
# 4. Final gloss of the filling
#
# Answer: 3
# 23 serotypes pneumococcal vaccine Most useful in
# choose only one of the following options:
# 1. Cystic fibrosis
# 2. Recurrent otitis media & sinusitis
# 3. Child less than 2 years
# 4. Sickle cell anaemia
# 5. HIV infection
#
#
# RNAi causes the following in a gene:
# choose only one of the following options:
# 1. Knock in
# 2. Knock out
# 3. Knock down
# 4. Knock up
#
# Answer: 3
# Which of the following amino acids does not include post-translational modification?
# choose only one of the following options:
# 1. Selenocysteine
# 2. Triiodothyronine
# 3. Hydroxyproline
# 4. Hydroxylysine
# Answer: Triiodothy
# The skin of a patient undergoing radiotherapy will show
# after 2 weeks?
# choose only one of the following options:
# 1. Erythema
# 2. Depigmentation
# 3. Radiation induced carcinomas
# 4. No change
# Answer:
# 1
# 45 chromosomes are seen in
# choose only one of the following options:
# 1. Turner's syndrome
# 2. Down's syndrome
# 3. Dentinogenesis imperfecta
# 4. Treacher's Collins syndrome
#
# Answer: None of
# Regional Odontodysplasia is most common in
# choose only one of the following options:
# 1. Mandibular premolar
# 2. Mandibular canine
# 3. Mandibular third molar
# 4. Maxillary central incisor
#
# Answer:
#
# T-lymphocytes play a primary role in
# choose only one of the following options:
# 1. Production of Antibodies
# 2. Production	of	lymphokines	and	delayed hypersensitivity
# 3. Activation of complement system
# 4. Immediate Hypersensitivity
#
# T-lymph
# Mean and standard deviation can be worked out only if data is on -
# choose only one of the following options:
# 1. Interval/Ratio scale
# 2. Dichotomous scale
# 3. Nominal scale
# 4. Ordinal scale
#
# Answer: Mean and
# For a loose complete denture relining and rebasing can be done in which of the following condition
# choose only one of the following options:
# 1. Excessive alveolar bone loss
# 2. When centric relation and centric occlusion do not coincide
# 3. The patient is poor and cannot afford new denture
# 4. More than 2mm loss of alveolar bone height
#
# Answer: 1
# The deepest layer of cervical fascia is:
# choose only one of the following options:
# 1. Vertebral
# 2. Carotid sheath
# 3. Deep fascia
# 4. Prevertebral fascia
#
# Answer: Prever
# The disturbances occurred during "Calcification" stage of tooth development is seen in:
# choose only one of the following options:
# 1. Peg laterals
# 2. Microdontia
# 3. Supernumerary tooth
# 4. Interglobular dentin
#
# Answer: Interglob
# Fovea palatine are
# choose only one of the following options:
# 1. Structures through which blood supply take place
# 2. Mucosal salivary glands
# 3. Palatal termination of maxillary denture
# 4. Found in every individual's nasal cavity
#
# Dustless alginate is produced by
# choose only one of the following options:
# 1. Reducing the diatomaceous earth
# 2. Adding heavy metal salts
# 3. Coating with dihydric alcohol
# 4. Altering the matrix structure
#
# Answer:
# Most commonly implicated drug for acute liver failure is -
# choose only one of the following options:
# 1. Paracetamol
# 2. Valproate
# 3. Warfarin
# 4. Tetracyclines
#
# Answer: 1
# Which of the following is characterized by Apple Jelly Nodules?
# choose only one of the following options:
# 1. Scrofula
# 2. Lupus vulgaris
# 3. Ghon’s focus
# 4. Ghon's complex
#
# Answer: None of
# A patient underwent laparoscopic cholecystectomy and was discharged on the same day. On postoperative day 3, he presented to the hospital with fever. Ultra-sonography showed a 5 x 5 cm collection in the right sub diaphragmatic region. What will be the manage!ment?
# choose only one of the following options:
# 1. Observe with antibiotic cover
# 2. Re-explore the wound with T-tube inseion
# 3. Pigtail inseion and drainage
# 4. ERCP and proceed with endoscopic retrograde
# Persons with the greatest risk of oral cancer
# choose only one of the following options:
# 1. Have a poor oro-dental hygiene, nutritional deficiencies and are chronic alcoholics
# 2. Are middle aged, have a poor oro-dental hygiene and regularly use tobacco
# 3. Are old, Chronic alcoholics and regularly use tobacco
# 4. Are young, have poor oro-dental hygiene and are heavy smokers
#
# Answer: 2
# The probable reasons for a high incidence of dental caries in the teenage population relates most directly to:
# choose only one of the following options:
# 1. Rapid growth
# 2. Frequency of sucrose intake
# 3. Negligence in visiting the dentist
# 4. Carelessness in oral hygiene habits
# Answer: 2.
# Shape of 1st Maxillary molar
# choose only one of the following options:
# 1. Rhomboid
# 2. Rounded triangular
# 3. Trapezoid
# 4. Square
#
# Answer: 3
# The antidote for heparin is:
# choose only one of the following options:
# 1. Penicillinase
# 2. Protamine sulphate
# 3. Pryosulphate
# 4. Potassium sulphate
#
# Answer: 2
# Resin teeth:
# choose only one of the following options:
# 1. Show a high compressive strength
# 2. Contraindicated in patients with decreased inter occlusal distance
# 3. Show crazing
# 4. Show a high fracture strength
# 5. Show a high wear
# Medial dislocation of fractured condyle in subcondylar fracture is caused by
# choose only one of the following options:
# 1. Lateral pterygoid
# 2. Medial pterygoid
# 3. Masseter
# 4. Temporalis
# Answer: 1.
# ECG with "mean" axis of 90deg. In which lead there would be the maximum voltage of R wave?
# choose only one of the following options:
# 1. III
# 2. I
# 3. aVF
# 4. aVL
#
# Answer: 1
# Most common site of esophageal carcinoma?
# choose only one of the following options:
# 1. Middle 1/3rd of esophagus
# 2. Upper 2/3rd of esophagus
# 3. Lower 2/3rd of esophagus
# 4. Middle 2/3rd of esophagus
#
# Answer: Lower
# Lateral pedicle flap is used for
# choose only one of the following options:
# 1. Increasing the width of attached gingiva
# 2. Recession coverage
# 3. Curettage
# 4. Vestibular deepening
#
# Answer: 2
# Best way to monitor perfusion of free flap:
# choose only one of the following options:
# 1. Pulse oximeter
# 2. Laser doppler velocimetery
# 3. Prick test
# 4. Flourescin & dermo flourometer
# Answer: 3.
# Sealants are effective in
# choose only one of the following options:
# 1. Initial caries
# 2. Secondary caries
# 3. Recurrent caries
# 4. Rampant caries
#
# Answer:
#
# Cephalosporin	active	against	pseudomonas
# aeruginosa
# choose only one of the following options:
# 1. Cefoperazone
# 2. Cefaclor
# 3. Ceftriaxone
# 4. Cefotaxime
# Answer: 3.
# Which anti-cholinergic drug doesn't cross the blood brain barrier and placenta?
# choose only one of the following options:
# 1. Glycopyrrolate bromide
# 2. Hyoscine bromide
# 3. Hyoscine butylbromide
# 4. Atropine sulfate
#
# Answer
# A person with histrionic, shy, anxious avoidant per!sonality comes under which cluster?
# choose only one of the following options:
# 1. A
# 2. B
# 3. C
# 4. D
# Answer: C. The
# Best index to measure cardiac afterload is:
# choose only one of the following options:
# 1. Mean aerial pressure
# 2. LV end diastolic pressure
# 3. LV mean systolic pressure
# 4. Total peripheral resistance
# Answer: 4.
# A 27 years old lady with 20 weeks pregnancy presented with a thyroid nodule on right side. FNAC from the nodule was suggestive of papillary carcinoma. Which of the following is contraindicated in her management?
# choose only one of the following options:
# 1. Total thyroidectomy plus neck node dissection
# 2. Right lobectomy
# 3. Radioactive iodine ablation
# 4. Total thyroidectomy
#
# Answer: 1
# Which of the following is having Maximum buffering capacity
# choose only one of the following options:
# 1. Histidine
# 2. Cysteine
# 3. Tyrosine
# 4. Arginine
#
# Answer:
# Arg
# What is the most common tumor of mediastinum?
# choose only one of the following options:
# 1. Neurogenic
# 2. Thymoma
# 3. Lymphoma
# 4. Metastatic tumor
#
# Answer: Thym
# What is under-5 moality' rate in world by 2010?
# choose only one of the following options:
# 1. 6 million
# 2. 8 million
# 3. 10 million
# 4. 12 million
#
# The under-5 mort
# Which of the following scoring system is used for wound infection?
# choose only one of the following options:
# 1. ASA score
# 2. SIRS score
# 3. Southampton score
# 4. Glasgow score
#
# Answer: 3
# A patient comes with pinpoint pupil, salivation, tremors, and red tears. Cholinesterase activity was 30% normal. Probable diagnosis is:
# choose only one of the following options:
# 1. Opium
# 2. Organophosphate poisoning
# 3. Dhatura
# 4. Organochloride pesticide poisoning
#
# The correct answer is:
# A permanent tooth with fracture involving apical one
# third of root after treatment, would most likely:
# choose only one of the following options:
# 1. Exhibit internal root resorption
# 2. Remain vital and functional
# 3. Be ankylosed
# 4. Exhibit external root resorption and exfoliate
# Answer: 1.
# In case of nodal metastasis, which is not seen on CT scan
# choose only one of the following options:
# 1. Spiculated node
# 2. Size more than 6 mm
# 3. Necrotic node
# 4. Rounded node
#
# Answer: The correct
# Which component of zinc oxide-eugenol cement gives its strength?
# choose only one of the following options:
# 1. Rosin
# 2. Zinc oxide
# 3. Zinc acetate
# 4. Oil of cloves
#
# Answer: 2
# An 8 year old child got trauma and got his central incisor avulsed 20 minutes back which got contaminated with debris. The child rushes to dental clinic with avulsed tooth, the treatment is:
# choose only one of the following options:
# 1. Clean root surface with saline and reimplant
# 2. Clean and curette root surface and reimplant
# 3. Clean root surface, do RCT and reimplant
# 4. Scrubbing of root surface and reimplant
#
# Answer: 1
# A patient underwent thyroidectomy for hypehyroidism. Two days later he was presented with features of thyroid storm. What is the most likely cause?
# choose only one of the following options:
# 1. Poor antibiotic coverage
# 2. Rough handling during surgery
# 3. Removal of parathyroid
# 4. Inadequate preoperative preparation
#
# The most likely cause is
# A G2 P1+0+0 diabetic mother present at 32 weeks pregnancy, there is history of full term fetal demise in last pregnancy. Her vitals are stable, sugar is controlled and fetus is stable. Which among the following will be the most appropriate management?
# choose only one of the following options:
# 1. To induce at 38 weeks
# 2. To induce at 40 weeks
# 3. Cesarean section at 38 weeks
# 4. To wait for spontaneous delivery
#
# Answer:
# Based
# The depth of clinical gingival sulcus is the distance between the gingival margin to the
# choose only one of the following options:
# 1. Cementoenamel Junction
# 2. Alveolar crest
# 3. Apical extension of junctional epithelium
# 4. Apical penetration of the probe
#
# Answer: 1
# Dunlop's beta hypothesis is useful for the treatment of:
# choose only one of the following options:
# 1. Bruxism.
# 2. Thumb sucking.
# 3. Mouth breathing.
# 4. Tongue thrusting.
#
# Answer: 1
# A 2 year old boy has vitamin D refractory rickets. Investigations show serum calcium 9 mg/dl. Phosphate 2.4 mg dl, alkaline phosphate 1040 parathyroid hormone and bicarbonate levels are normal. The most probable diagnosis is –
# choose only one of the following options:
# 1. Distal renal tubular acidosis
# 2. Hypophosphatemic rickets.
# 3. Vitamin D dependent rickets
# 4. Proximal renal tubular acidosis
#
# Answer: 1
# A patient comes to a dentist with decayed mandibular 1st molar which involves the mesiobuccal and distobuccal cusp. The restoration of choice is:
# choose only one of the following options:
# 1. Intermediate restoration
# 2. Composite
# 3. Cast metal
# 4. GIC
#
# Answer: 3
# Which of the following parameters is used to determine the sensitivity of vaccine due to heat?
# choose only one of the following options:
# 1. VVM
# 2. VMV
# 3. VCM
# 4. VMM
# Answer: 1.
# A breast fed child presents with hypernatremia (Serum sodium > 170m Eq/L). His urine sodium is 70 mEq/L. Which of the following is the most likely cause –
# choose only one of the following options:
# 1. Diabetes insipidus
# 2. Acute necrosis
# 3. Severe dehydration
# 4. Excessive intake of sodium
#
# Answer:
# The
# For which of the following, you will not perform pulpectomy?
# choose only one of the following options:
# 1. Primary teeth with sinus tract
# 2. Primary teeth without successor
# 3. Primary teeth with furcation pathology
# 4. Pulpless primary teeth next to the line of a palatal cleft
#
# Answer: 2
# Which of the following is the least useful for diagnosis of Spondylolisthesis?
# choose only one of the following options:
# 1. CT
# 2. MR
# 3. X-ray lumbar spine- AP view
# 4. X-ray lumbar spine- Lateral view
# Answer:
# 1.
# In a patient with obstructive jaundice, what is the possible explanation for a bilirubin level of 40 mg/dL?
# choose only one of the following options:
# 1. Malignant obstruction
# 2. Complete obstruction of common bile duct
# 3. Renal failure
# 4. Liver failure
#
# The possible explanation for a
# An oral hypoglycemic agent is:
# choose only one of the following options:
# 1. Warfarin
# 2. Insulin
# 3. Glibeneclamide
# 4. Gluengonadine
#
# Correct answer
# Which of the following vitamin increases the absorption of iron?
# choose only one of the following options:
# 1. Vitamin A
# 2. Vitamin C
# 3. Thiamin
# 4. Riboflavin
#
# Answer: 2
# Which of the following has least density?
# choose only one of the following options:
# 1. VLDL
# 2. LDL
# 3. HDL
# 4. Chylomicrons
#
# Answer: Chyl
# Treatment of choice for a patient with gonococcal as well as non-gonococcal urethritis is:
# choose only one of the following options:
# 1. Ceftriaxone 250 mg IM single dose
# 2. Cefixime 400 mg oral single dose
# 3. Ciprofloxacin 500 mg oral single dose
# 4. Azithromycin 2 g oral single dose
#
# Answer: 1
# A G3P2, pregnant comes to your clinic at 18 weeks of gestation for genetic counselling. She has a history of two kids born with thalassemia major. Which test would you recommend now?
# choose only one of the following options:
# 1. Amniocentesis
# 2. Chorionic villus sampling
# 3. Cordocentesis
# 4. Non-invasive prenatal testing
#
# Answer:
# Based
# Brachcephaly with narrow foramen magnum is seen in:
# choose only one of the following options:
# 1. Down syndrome.
# 2. Fanconi syndrome.
# 3. Achondroplasia.
# 4. Cleidocranial dysplasia.
#
# Answer: 1
# What is the usual weight of rabbit used in ophthalmological experiments?
# choose only one of the following options:
# 1. 0.5-1 kg
# 2. 1.5-2.5 kg
# 3. 5-7 kg
# 4. 10-12 kg
#
# Answer: 1
# A 60-year-old chronic smoker presented with progres-sive jaundice, pruritus and clay colored stools for 2 months. History of waxing and waning of jaundice was present. A CT scan revealed dilated main pancre-atic duct and common bile duct. What is the likely di-agnosis?
# choose only one of the following options:
# 1. Carcinoma head of pancreas
# 2. Periampullary carcinoma
# 3. Chronic pancreatitis
# 4. H lar cholangiocarcinoma
# Answer: 2.
# Sugar restricted to diet was beneficial in presence of unfavorable hygiene was from which study?
# choose only one of the following options:
# 1. Hopewood
# 2. Experimental
# 3. Vipeholm
# 4. Turku
#
# Answer: 3
# Countercurrent mechanism is not seen in:
# choose only one of the following options:
# 1. Kidney
# 2. Testes
# 3. Eye
# 4. Intestine
#
# Answer: Testes
# Marked reduction in amount of dentin, widening of predentin layer, presence of large area of interglobular dentin and irregular pattern of dentin is seen in
# choose only one of the following options:
# 1. Hypocalcified dentin
# 2. Odonto dysplasia
# 3. Dentin dysplasia
# 4. Dentinogenesis imperfecta
#
# Answer: Dentin
# Normal growth of maxilla occurs by
# choose only one of the following options:
# 1. Displacement and drift
# 2. Drift only
# 3. Apposition
# 4. Replacement resorption
#
# Answer:
#
# Macrocephaly is seen in which of the following syndromes ?
# choose only one of the following options:
# 1. Metachromatic leucodystrophy
# 2. Adrenoleukodystrophy
# 3. Canavan's disease
# 4. Krabbe's disease
#
# Answer: 3
# Bone better described as "bat with extended wings" is:
# choose only one of the following options:
# 1. Ethmoid
# 2. Sphenoid
# 3. Nasal
# 4. Mandible
#
# Answer: 4
# At 28 weeks gestation, amniocentesis reveals a AOD 450 of 0.20 which is at the top of third zone of the liley curve. The most appropriate management of such a case is:
# choose only one of the following options:
# 1. Immediate delivery
# 2. Intrauterine transfusion
# 3. Repeat Amniocentesis after 1 week
# 4. Plasmapheresis for the mother
#
# Answer
# In which of the following glucocoicoid is used?
# choose only one of the following options:
# 1. E.coli septicemia
# 2. Severe typhoid
# 3. Cerebral Malaria
# 4. Leishmaniasis
#
# Answer: None of
# Infective endocarditis is most commonly seen in:
# choose only one of the following options:
# 1. ASD
# 2. VSD
# 3. PDA
# 4. Pulmonary stenosis
# Answer: All of the
# Which of the following has a male:female ratio of 1:1?
# choose only one of the following options:
# 1. Rheumatoid ahritis
# 2. Gout
# 3. Seronegative spondyloahritis
# 4. Polymyalgia rheumatica
# Answer:
# Polym
# Monitoring and diagnosis after completion of H. pylori treatment is done through
# choose only one of the following options:
# 1. Gastric acid test
# 2. urea breath test
# 3. bacterial culture of stool
# 4. sodium chloride test
# Answer: 2.
# A patient with Tubercular meningitis was taking ATT regularly. At end of 1 month of regular intake of drugs deterioration in sensorium is noted in condition of the patient despite good compliance for drugs. Which of the following investigations is not required as emergency condition?
# choose only one of the following options:
# 1. MRI
# 2. NCCT
# 3. CSF examination
# 4. Liver function tests
# Answer: 4.
# During mandibular nerve block which nerve also gets damaged?
# choose only one of the following options:
# 1. Abducence
# 2. Facial
# 3. Vagus
# 4. Trochlear
#
# Answer: 1
# Recommnended daily intake of iodine in pregnancy-
# choose only one of the following options:
# 1. 90 microgram
# 2. 120 microgram
# 3. 150 microgram
# 4. 250 microgram
# Answer: The recommended daily
# Maximum strain of parturient heart occurs during:
# choose only one of the following options:
# 1. At term
# 2. Immediate postpartum
# 3. Ist trimester
# 4. IInd trimester
#
# Answer: 2
# Dark points on teeth along with tooth destruction of 4 years old patient
# choose only one of the following options:
# 1. ECC
# 2. Staining
# 3. Fluorosis
# 4. Deep caries
#
# Answer: 4
# Best investigation for metabolic disorders is?
# choose only one of the following options:
# 1. Western blot
# 2. Tandem mass spectrometry
# 3. PCR
# 4. Gel electrophoresis
#
# Answer: Tand
# In CRISPR-Cas 9 system, which repair mechanism is used for genome editing?
# choose only one of the following options:
# 1. Non homologous end repair
# 2. Homologous repair
# 3. Mismatch repair
# 4. Nucleotide excision repair
#
# Answer: 1
# Nucleus in brain common to IX, X and XI cranial nerves:
# choose only one of the following options:
# 1. Nucleus solitarius
# 2. Nucleus ambiguus
# 3. Dentate nucleus
# 4. Red nucleus
#
# Answer: 1
# Which of the following instructions should be given to a lactating mother regarding drug usage?
# choose only one of the following options:
# 1. No advice is required as most of the drugs are secreted negligibly in the milk
# 2. Take drugs with longer half-life
# 3. Tell her to feed the baby just before next dose
# 4. Do not feed the baby if you are consuming any drug
#
# Answer:
#
# Most difficult access cavity preparation is in
# choose only one of the following options:
# 1. Mandibular incisors
# 2. Mandibular Canine
# 3. Mandibular premolar
# 4. Mandibular molar
#
# Answer: Mandib
# Patellar cluck syndrome is interposition of soft tissue at or hyperophied scar:
# choose only one of the following options:
# 1. Superior pole of patella and impinging on femoral component during flexion
# 2. Superior pole of patella and impinging on femoral component during extension
# 3. Inferior pole of patella and impinging on femoral component during flexion
# 4. Inferior pole of patella and impinging on femoral component during extension
#
# Answer: 1
# Which of the following does golgi tendon organ detect?
# choose only one of the following options:
# 1. Muscle Tension
# 2. Dynamic muscle length
# 3. Static muscle length
# 4. Muscle action
#
# Answer: 1
# The protein rich in basic amino acids, which functions in the packaging of DNA in chromosomes, is:
# choose only one of the following options:
# 1. Histone
# 2. Collagen
# 3. Hyaluronic acid binding protein
# 4. Fibrinogen
#
# Answer: 1
# Innervation of pulp is from
# choose only one of the following options:
# 1. Trigeminal nerve
# 2. Facial nerve
# 3. Glossopharyngeal nerve
# 4. Hypoglossal nerve
#
# Answer: 1
# Premaxilla is derived from
# choose only one of the following options:
# 1. Maxillary protuberance
# 2. Palatine bones
# 3. Frontonasal process
# 4. Median process of the maxilla
#
# An
# A patient comes to your clinic with a complaint of multiple episodes of loose watery stool for 3 days. On probing, you discover that these episodes sta after he had ingested shellfish at a local restaurant 3 days back and other people who had food from that restaurant had similar symptoms. What is the most common cause of viral diarrhoea in adults?
# choose only one of the following options:
# 1. Calicivirus
# 2. Rotavirus
# 3. Adenovirus
# 4. Norovirus
# Answer: 4.
# A 4-year-old child has a normal complement of primary teeth, but they are grey and exhibit extensive occlusal and incisal wear. Radiographic examination indicates extensive deposits of secondary dentin in these teeth. Most likely this condition is:
# choose only one of the following options:
# 1. Neonatal hypoplasia
# 2. Amelogenesis imperfecta
# 3. Cleidocranial dysplasia
# 4. Dentinogenesis imperfecta
#
# Answer: 4
# Phase-contrast microscopy is based on the principle of:
# choose only one of the following options:
# 1. Different refractive indices of object
# 2. Different reflective indices of object
# 3. Light scattering
# 4. Light attenuation
# Answer: 1.
# Which of the following premolars has a mesial marginal ridge more cervical than the distal marginal ridge:
# choose only one of the following options:
# 1. Maxillary 1st premolar
# 2. Maxillary 2nd premolar
# 3. Mandibular 1st premolar
# 4. Mandibular 2nd premolar
#
# Answer:
# 1
# Natural disaster causing maximum deaths
# choose only one of the following options:
# 1. Hydrological
# 2. Meterological
# 3. Geological
# 4. Fires
#
# The natural disaster causing the
# Not a side effect of Escitalopram?
# choose only one of the following options:
# 1. Nausea
# 2. Vivid dreams
# 3. Anorgasmia
# 4. Sialorrhoea
#
# Answer:
# An
# ADA specification of orthodontic wire:
# choose only one of the following options:
# 1. 29
# 2. 25
# 3. 32
# 4. 30
#
# Answer: 3
# X,Y,Z are the ee ions pet meaule..\\ and V=-30. If at resting membrane potential (RMP), when there is no net electro genic transfer, what is the value of Z?
# choose only one of the following options:
# 1. 20
# 2. -20
# 3. 80
# 4. -80
#
# Answer:
# The
# Cumulative index is:
# choose only one of the following options:
# 1. Russet's periodontal index
# 2. Ramjford's periodontal index
# 3. PMA (Massler and Schlour)
# 4. Gingival index (Loe and Silness)
# 5. Plaque index (
# Malaria control means
# choose only one of the following options:
# 1. To reduce Malaria moality to Zero
# 2. To prevent local transmission for 3 years
# 3. To reduce Malaria disease so that its no longer a Public Health Problem
# 4. To reduce Incidence to Zero
#
# Answer: 3
# Which of the following is not an autoimmune disorder?
# choose only one of the following options:
# 1. Ulcerative colitis
# 2. Grave's disease
# 3. Rheumatoid ahritis
# 4. SLE (Systemic Lupus E
# Dentin conditioner has the following function.
# choose only one of the following options:
# 1. Removes smear layer
# 2. Increases surface energy of dentin
# 3. Forms a thin resin layer over exposed collagen fibrils
# 4. Helps in bonding with composite resin
#
# Answer:
# A 26-year-old primigravida with juvenile myoclonic epilepsy comes to you at 4 months with concern regarding continuing sodium-valproate treatment. Your advice is:
# choose only one of the following options:
# 1. Add lamotrigine to sodium valproate
# 2. Taper sodium valproate and add lamotrigine
# 3. Switch on to carbamazepine
# 4. Continue sodium valproate with regular monitoring of serum levels and liver function tests
#
# An
# Acromegaly occurs:
# choose only one of the following options:
# 1. Before closure of epiphyses of long bones
# 2. After closure of epiphyses of long bones
# 3. Not related to closure of epiphyses of long bones
# 4. Depending on functioning on posterior Pituitary gland
#
# Answer: 2
# Which of the following complications of stroke need not to be treated?
# choose only one of the following options:
# 1. Fever
# 2. Spasticity
# 3. Dysphagia
# 4. Numbness
#
# Answer: None of
# A 3.5 kg male infant born at term after an uncomplicated pregnancy and delivery develops respiratory distress sholy after bih and requires mechanical ventilation. The chest radiograph reveals a normal cardiothymic silhouette but a diffuse ground glass appearance to the lung fields. Surfactant replacement fails to improve gas exchange. Over the first week life, the hypoxemia worsens. Results of routing culture and echocardiographic findings are negative. A term female sibling died at 1 month of age with respiratory distress. Which of the following is the most likely diagnosis?
# choose only one of the following options:
# 1. Neonatal pulmonary alveolar proteinosis
# 2. Meconium aspiration
# 3. Total anomalous pulmonary venous return
# 4. Disseminated herpes simplex infection
#
# The most likely diagnosis is
# Deepest layer of deep cervical fascia is
# choose only one of the following options:
# 1. Prevertebral
# 2. Carotid sheath
# 3. Pretracheal
# 4. Temporal
#
# Answer: 1
# Maximum steroid produced by fetal adrenal:-
# choose only one of the following options:
# 1. DHEA-S
# 2. Coisol
# 3. Coicosterone
# 4. Progesterone
#
# Answer: 1
# "Strawberry Tongue" is  associated with
# choose only one of the following options:
# 1. syphilis
# 2. measles
# 3. scarlet fever
# 4. typhoid fever
#
# Answer:
# A 48-year old lady presented with bony pain and hepatosplenomegaly. On examination of biopsy speci!men from spleen, crumpled tissue paper appearance is seen. Which of the following product is likely to have accumulated?
# choose only one of the following options:
# 1. Ganglioside
# 2. Sulfatide
# 3. Sphingomyelin
# 4. Glucocerebroside
#
# Answer: 4
# Spinal cord ends at what level in adults?
# choose only one of the following options:
# 1. T12
# 2. L1
# 3. L2
# 4. L3
#
# Answer: 1
# The best radiograph to obtain a view of maxillary sinus is:
# choose only one of the following options:
# 1. Lateral oblique maxilla
# 2. Submentovertex
# 3. Waters view
# 4. Lateral skull
#
# Answer: 1
# Multiple punched out lesions are seen in:
# choose only one of the following options:
# 1. Paget's disease
# 2. Osteosarcoma
# 3. Ewing sarcoma
# 4. Multiple myeloma
#
# Answer: Multiple
# Which of the following is not a branch of external carotid artery
# choose only one of the following options:
# 1. Posterior auricular artery
# 2. Occipital artery
# 3. Maxillary artery
# 4. Ophthalmic artery
#
# Answer: 3
# Surgery on the hard palate of a 3 years old cleft patient may inhibit growth, causing the facial profile to become:
# choose only one of the following options:
# 1. Straight
# 2. Elongated
# 3. Shortened
# 4. More concave
#
# Answer: 3
# Which one of the following is a gender-specific side-effect of valproate?
# choose only one of the following options:
# 1. Polycystic ovarian syndrome
# 2. Alopecia
# 3. Weight loss
# 4. Tremor
#
# Answer: 1
# ECG shows a mean axis of 90 degrees. In which of the following would be present the maximum voltage of R wave?
# choose only one of the following options:
# 1. III
# 2. I
# 3. aVF
# 4. aVL
#
# Answer: 1
# Inlay wax is used to:
# choose only one of the following options:
# 1. Temporarily cement inlays
# 2. Make inlay wax patterns
# 3. Invest inlay patterns
# 4. Box models for crowns and bridges
#
# Artery palpable at the anterior border of the masseter is :
# choose only one of the following options:
# 1. Superficial temporal artery
# 2. Facial artery
# 3. Lingual artery
# 4. Maxillary artery
#
# Answer: 4
# Biopsy specimens removed for examinations are immediately placed in:
# choose only one of the following options:
# 1. 10% ethanol
# 2. 10% formalin
# 3. Hydrogen peroxide
# 4. 1% formalin
#
# Answer: 2
# To check objective pain response, which is best used method
# choose only one of the following options:
# 1. Facial pain scale
# 2. Knee jerk reflex
# 3. H - Reflex
# 4. R III Reflex
#
# Answer: 2
# Which of the following is the most common organism found in retreatment cases of periapical abscess?
# choose only one of the following options:
# 1. E. faecalis
# 2. Trepenoma denticola
# 3. S. mutans
# 4. Actinomyces israelii
# Answer:
# Deepening the pulpal floor during cavity preparation
# provides for
# choose only one of the following options:
# 1. Outline form
# 2. Retention form
# 3. convenience form
# 4. Resistance form
# Answer: 3.
# SD plasma destroys lipid enveloped virus. On SD plasma transfusion, which of the following infection is the likely possibility?
# choose only one of the following options:
# 1. HIV
# 2. HAV
# 3. HBV
# 4. HCV
# Answer: 1.
# Which of the following best describes paradoxical suicide?
# choose only one of the following options:
# 1. Suicide after taking low dose of drug
# 2. Suicide occurring at the time when the pt. stas to recover
# 3. Suicidal tendency increase as the patient improves
# 4. Accidental completion of suicide while attempting to harm self
#
#
# Malignant peripheral nerve sheath tumour showing which of the following differentiation is termed as "Triton tumour"?
# choose only one of the following options:
# 1. Glandular
# 2. Rhabdomyoblastic
# 3. Cailaginous
# 4. Osseous
#
# Answer: 2
# Amalgam restorations give the best clinical service when the residual mercury content is:
# choose only one of the following options:
# 1. 38-42%
# 2. 48-52%
# 3. 58-62%
# 4. 68-72%
# Answer: 1.
# In case of Fracture of mandible; alveolar border experiences which force
# choose only one of the following options:
# 1. Tension
# 2. Compression
# 3. Torsion
# 4. Rotation
# Answer: Compression.
# Autogenic inhibition is afunction of
# choose only one of the following options:
# 1. Intrafusal fibre
# 2. Extrafusal fibre
# 3. Muscle spindle
# 4. Golgi tendon organ
#
# Answer: 1
# Low apparent volume of distribution of a drug indicates That
# choose only one of the following options:
# 1. Drug has low half life
# 2. Drug has low bioavailability
# 3. Drug has low efficacy
# 4. Drug is not extensively distribution to tissue
#
# Answer: 4
# Sclerotic dentin has following features:
# choose only one of the following options:
# 1. Caries susceptible
# 2. Insensitive
# 3. Hypersensitive
# 4. Resistant to caries
#
# Answer: 2
# Fenestri vestibuli is:
# choose only one of the following options:
# 1. Rounded bulge produced by first turn of cochlea
# 2. Oval opening posterosuperior to the promontory
# 3. Prominence produced due to the lateral semicircular canal
# 4. It is grooved by tympanic plexus
#
# Answer: 2
# Long term assessment of glucose control can be made by:
# choose only one of the following options:
# 1. Estimation of post prandial blood sugar
# 2. Estimation of fasting blood sugar
# 3. Estimation of urine sugar level
# 4. Estimation of blood level of glycosylated hemoglobin (HbA1c)
# Which of the following is maximum in HDL as compared to other lipoproteins?
# choose only one of the following options:
# 1. Cholesterol
# 2. Apoproteins
# 3. Triglycerides
# 4. Fatty acids
#
# Answer: 2
# Patient presented with imbalance on walking with eyes closed and has to lift up foot and stomp on ground to walk. The tract involved is:-
# choose only one of the following options:
# 1. Spinocerebellar tract
# 2. Dorsal column tract
# 3. Lateral spinothalamic tract
# 4. Vestibulospinal tract
# Answer: 4.
# Dengue discharge protocol includes
# choose only one of the following options:
# 1. 24 hours after Recovery from shock
# 2. Urine volume > 200 ml
# 3. 24 hours after absence of fever with use of Paracetamol
# 4. Return of normal appetite
#
# Answer: 3
# Apical foramen is found at root apex in
# choose only one of the following options:
# 1. 17-46% of cases
# 2. 5-10 % of cases
# 3. 10-30% of cases
# 4. 100% of cases
#
# Answer: 1
# Correlation between the height and weight of children is best represented by:
# choose only one of the following options:
# 1. Histogram
# 2. Line diagram
# 3. Scatter diagram
# 4. Bar diagram
#
# Answer: 3
# Difference between the size of the cranium and the cephalogram is:
# choose only one of the following options:
# 1. No difference
# 2. 5% reduction
# 3. 5% enlargement
# 4. 10% enlargement
#
# Answer: 1
# Manufaeturer of a drug company labels that the drug contains 500 mg of paracetamol. On analysis' if was found to contain only 200 mg of drug. Which type of drug it is known as?
# choose only one of the following options:
# 1. Counterfeit drug
# 2. Adulterant drug
# 3. Spurious drug
# 4. Unethical drug
#
# Answer: 2
# An apical radiolucent area present in central incisor
# after 4 months of RCT is due to:
# choose only one of the following options:
# 1. Inadequate obturation & leakage from main canal
# 2. Leakage from accessory canal
# 3. Leakage from gingival crevice
# 4. Leakage from access opening
#
# Answer: 1
# In a school bus accident, which of the following victim you will attend first?
# choose only one of the following options:
# 1. A child with Airway obstruction
# 2. A child with shock
# 3. A child with flail chest
# 4. A child with Severe head injury
#
# Answer:
# 1
# Which teeth are least involved in periodontitis?
# choose only one of the following options:
# 1. Lower incisor and lower molar
# 2. Lower premolar and upper canine
# 3. Upper molars and upper incisors
# 4. Lower incisors and upper molars
#
# Answer: 2
# Kamla 4 yrs of age presented in emergency with mild respiratory "stress. On laryngoscopy she was diagnosed to have multiple juvenile papilomatosis of the larynx. Next line of management is -
# choose only one of the following options:
# 1. Tracheostomy
# 2. Microlaryngoscopy
# 3. Steroid
# 4. Antibiotics
#
# Answer: 2
# In fracture of atrophic mandible with bone loss, what is the best treatment modality?
# choose only one of the following options:
# 1. Bone grafting and load bearing
# 2. Bone grafting and load sharing
# 3. Semi-rigid fixation
# 4. IMF with open reduction
#
# Answer: 1
# Fixed drug eruptions are frequently seen with?
# choose only one of the following options:
# 1. Penicillin
# 2. Sulfonamide
# 3. Cetirizine
# 4. Roxithromycin
#
# Answer: 1
# Which of the following has a bifid root?
# choose only one of the following options:
# 1. 32, 42
# 2. 31, 41
# 3. 34, 44
# 4. 13, 23
# Answer:
# None of
# Which is the most numerous component of plaque?
# choose only one of the following options:
# 1. Minerals
# 2. Food debris
# 3. Microorganisms
# 4. Leucocytes
# Answer: 1.
# Which of these is the most reliable method for monitoring fluid resuscitation?
# choose only one of the following options:
# 1. Urine output
# 2. CVP
# 3. Pulse rate
# 4. Blood pressure
# Answer: 1.
# Which of these is pierced during posterior superior alveolar nerve Block?
# choose only one of the following options:
# 1. Medial Pterygoid
# 2. Lateral Pterygoid
# 3. Buccinator
# 4. Masseter
#
# Answer: None of
# Increase in the residual mercury in silver amalgam filling can:
# choose only one of the following options:
# 1. Cause fracture of the filling
# 2. Tarnish and corrosion
# 3. Increase the strength
# 4. Decrease condensation pressure
#
# Answer: 1
# Calcium ions triggers muscle contraction by binding to:
# choose only one of the following options:
# 1. Actin
# 2. Myosin
# 3. Troponin
# 4. Tropomyosin
#
# Correct answer: Tro
# Distance of the blade from the shank to have antirotational stability of the instrument?
# choose only one of the following options:
# 1. 2 mm
# 2. 3 mm
# 3. 4 mm
# 4. 5 mm
# Answer: 3 mm
# Umblical cord contains:
# choose only one of the following options:
# 1. 3 arteries & 1 vein
# 2. 1 artery& 3 veins
# 3. 1 artery & 1 vein
# 4. 2 arteries & 1 vein
#
# Answer: 1
# The optimal time to employ an orthodontic appliance that takes advantage of growth is during:
# choose only one of the following options:
# 1. Late mixed dentition
# 2. Early mixed dentition
# 3. Late primary dentition
# 4. Early permanent dentition
# Answer:
# 3
# 10-year-old boy visits dentist with complicated crown fracture with abscess formation in 12. X-ray reveals radiolucency in relation to 11, 12. 12 is having immature  blunderbuss canal while 11 has complete root formation, vitality of 11, 21 is negative. What would be the management of this patient?
# choose only one of the following options:
# 1. Apexification of 12 and RCT of 11
# 2. Revascularization in 12 and RCT of 11
# 3. RCT of 12 and 11
# 4. Extraction of 12 and RCT in 11
#
# Answer: 1
# Atropine is not an antidote in:
# choose only one of the following options:
# 1. Tik 20
# 2. Endrin
# 3. Baygon
# 4. Parathion
# Answer: 1.
# A baby presents with tetany. First thing to be done is administration of :
# choose only one of the following options:
# 1. Diazepam
# 2. Vitamin D
# 3. Calcium gluconate
# 4. Calcitonin
#
# Answer: Calci
# Which combination forms day care anesthesia
# choose only one of the following options:
# 1. Fentanyl, propofol, Isoflurane
# 2. Pethidine, Propofol, Isoflurane
# 3. Thiopental pethidime, Halothane
# 4. Thiopentane, isoflurane fantanyt
#
# Answer: 1
# Which is associated with defect in DNA repair
# choose only one of the following options:
# 1. Xeroderma pigmentosum
# 2. Albinism
# 3. Icthyosis
# 4. Sickle cell anaemia
#
# Answer: 1
# Pulsatile varicose veins in lower limbs is seen in –
# choose only one of the following options:
# 1. Klippel trenaunay syndrome
# 2. TR
# 3. RV failure
# 4. Carcinoid stenosis of tricuspid valve
#
# Answer:
# Not responsible for chronic gingival inflammation?
# choose only one of the following options:
# 1. Neutrophil
# 2. Macrophages
# 3. T-lymphocytes
# 4. Plasma cells
#
# Answer: 1
# The best finish line for anterior metal ceramic crown is
# choose only one of the following options:
# 1. Chamfer with bevel
# 2. Heavy chamfer
# 3. Shoulder
# 4. Shoulder with bevel
#
# Answer: The best
# Lymph from tongue not drained by following vessels
# choose only one of the following options:
# 1. Central
# 2. Ventral
# 3. Posterior
# 4. Marginal
#
# Answer: The l
# In leukemia patient, post extraction bleeding doesn't stop because of:
# choose only one of the following options:
# 1. Increased leukocyte count
# 2. Increased Ca+ level in blood
# 3. Platelet disorder
# 4. Deficiency of clotting factors
#
# Answer: 3
# The instrument shown in fig is used for
# choose only one of the following options:
# 1. Rapid separation
# 2. Slow separation
# 3. Not used for separation
# 4. Depends on force for separation
# Answer: 1.
# Occurrence of malocclusion in given population is best described as:
# choose only one of the following options:
# 1. Prevalence rate
# 2. Incidence rate
# 3. Morbidity
# 4. Probability
#
# Answer: 1
# Lower 2nd molar has
# choose only one of the following options:
# 1. ‘+’ shape
# 2. Distorted ‘+’ shape
# 3. Y shaped
# 4. H shaped
#
# Answer: 1
# Extra-embryonic mesoderm is derived from:
# choose only one of the following options:
# 1. Epiblast
# 2. Primary yolk sac
# 3. Secondary yolk sac
# 4. Hypoblast
#
# Answer: 4
# A neuralgia with trigger zones in the oropharynx and pain
# in the ear pharynx, nasopharynx, tonsils and posterior tongue is most likely:
# choose only one of the following options:
# 1. Trigeminal neuralgia
# 2. Bell's patsy
# 3. GlossopharyngeaL neuralgia
# 4. Sphenopalatine neuralgia
#
# Answer: 3
# An 8 year old boy complaints of increasing muscle weakness. On examination, his calves are bulky and show muscle tightening. His serum creatine kinase levels are increasing with age. Which of the following is the most likely diagnosis?
# choose only one of the following options:
# 1. Hereditary sensorimotor neuropathy
# 2. Myelin deficiency
# 3. Dystrophin deficiency
# 4. Congenital myopathy
#
# The most likely diagnosis based
# Vitamin K dependent factor is
# choose only one of the following options:
# 1. II
# 2. III
# 3. IV
# 4. VI
#
# Answer: II.
# Good contacts in primary teeth with lack of spacing predicts?
# choose only one of the following options:
# 1. Normal occlusion in permanent teeth
# 2. Crowding in permanent teeth
# 3. Anterior cross bite
# 4. Spaced permanent dentition
#
# Answer: 1
# A drug X was given continuous intravenous infusion at 1.6 mg/min. The clearance of the drug is 640 mL/min. With a half-life of 1.8 hours, what would be the steady state plasma concentration of drug?
# choose only one of the following options:
# 1. 0.002 mg/mL
# 2. 0.004 trig/mL
# 3. 2.88 mg/mL
# 4. 3.55 mg/mL
#
# To find the steady state
# Which of the following is not a behavioral theory:
# choose only one of the following options:
# 1. Cognitive theory.
# 2. Hierarchy of needs.
# 3. Social learning.
# 4. Classical conditioning.
#
# Answer:
# The
# A non synovial joint with connective tissue in between is:
# choose only one of the following options:
# 1. Syndesmosis
# 2. Synchondrosis
# 3. Saddle
# 4. Suture
# Answer: 1.
# In a middle aged female swelling that presents in the midline of neck is most likely originating from:
# choose only one of the following options:
# 1. Larynx
# 2. Trachea
# 3. Thyroid
# 4. Hyoid bone
# Answer: 3
# Which of the following should be treated by using a
# tissue conditioner material?
# choose only one of the following options:
# 1. Tissue symptoms related to diabetes mellitus
# 2. Generalized ridge hyperplasia
# 3. Traumatized mucosa caused by ill fitting dentures
# 4. Sharp residual ridge in molar area
# Answer:
# 3.
# Tubercle of zukerkandle is seen on
# choose only one of the following options:
# 1. MB on upper and lower primary 1st molar
# 2. MB on upper and lower permanent 1st molar
# 3. MB on upper Primary 1st molar only
# 4. MB on lower primary 1st molar only
#
# Answer: 2
# Fill the missing data in the Ottawa charter for health promotion
# choose only one of the following options:
# 1. Promotion of health services
# 2. Reorienting health services
# 3. Prevention of disease
# 4. Effective health services
# 5. Creating supportive environments
# The diameter of the tip of a periodontal probe is:
# choose only one of the following options:
# 1. 0.25 mm
# 2. 0.75 mm
# 3. 0.5 mm
# 4. 1 mm
# Answer: The diameter of
# 3.5 kg term male baby, born of uncomplicated pregnancy, developed, respiratory distress at birth, not responded to surfactant, ECHO finding revealed nothing abnormal, X–ray showed ground glass appearance and culture negative. Apgars 4 and 5 at 1 and 5 minutes. History of one month female sibling died before. What is the diagnosis ?
# choose only one of the following options:
# 1. TAPVC
# 2. Meconium aspiration
# 3. Neonatal pulmonary alveolar proteinosis
# 4. Diffuse herpes simplex infection
#
# The symptoms described in the
# Golgi tendon organs detect:
# choose only one of the following options:
# 1. Static muscle length
# 2. Dynamic muscle length
# 3. Muscle tension
# 4. Muscle action
#
# Answer: 3
# Average daily dose of vitamin-C is:
# choose only one of the following options:
# 1. 30 - 40 mg
# 2. 50 - 60 mg
# 3. 60 - 100 mg
# 4. 100 - 150 mg
#
# Answer: 3
# Surgery of the cleft lip should be carried out at:
# choose only one of the following options:
# 1. 20 -30 weeks
# 2. 2 - 12 months
# 3. 3 - 6 months
# 4. 5 years
#
# Answer: 2
# In fixed orthodontic treatment, how much force is needed for intrusion of four mandibular anterior teeth:
# choose only one of the following options:
# 1. 50 gm
# 2. 100gm
# 3. 150gm
# 4. 200gm
#
# Answer: 1
# Mother of a 10 month old child came with a complaint of non-eruption of teeth, what will be the treatment protocol?
# choose only one of the following options:
# 1. Wait and watch
# 2. You will do OPG which shows developing tooth buds
# 3. PA skull view which shows developing tooth buds
# 4. Paediatric consultation
#
# Answer: 1
# ...
# 1. Parametric test based on average
# 2. Non parametric test based on average
# 3. Parametric test based on variance
# 4. Non parametric test based on variance
#
# Answer: 1
# A 50 years old male presented with frontal bossing, enlarged nasal bone, enlarged jaw and spade like fingers. Which of the following test will you do for diagnosis?
# choose only one of the following options:
# 1. IGF1
# 2. ACTH
# 3. TSH
# 4. Serum coisolamide level
# Answer:
# A 8-years-old patient with a supernumerary tooth and crowding in the arch comes to you; what will be your line of treatment:
# choose only one of the following options:
# 1. Wait and watch
# 2. Extraction and orthodontic treatment
# 3. Serial extraction
# 4. Immediate intervention with removal appliance
#
# Answer:
# Based
# A man has 1x1.5cm pedunculated lesion on the soft palate which has a rough, "warty" surface but is the same colour as adjacent mucosa. Appropriate management of this lesion is to:
# choose only one of the following options:
# 1. Perform an incisional biopsy
# 2. Perform excisional biopsy
# 3. Scrape for exfoliative cytology
# 4. Observe for two weeks
#
# Answer: 1
# Which of the following is most common developmental cyst
# choose only one of the following options:
# 1. Nasopalatine cyst
# 2. Naso-alveolar cyst
# 3. Globulomaxillary cyst
# 4. Median palatal cyst
#
# Answer: 1
# Lenolin is added in ZOE paste to:
# choose only one of the following options:
# 1. Decrease flow
# 2. Increase flow
# 3. Accelerate reaction
# 4. Decrease irritation due to eugenol
#
# Answer: 4
# In rheumatoid arthritis there is inflammation of:
# choose only one of the following options:
# 1. Cartilage
# 2. Synovial membrane
# 3. Sclerosis of joints
# 4. Articular bone
#
# Answer: 2
# In which of the following conditions would maternal serum alpha-fetoprotein values be the highest:
# choose only one of the following options:
# 1. Down's syndrome
# 2. Omphalocele
# 3. Gastroschisis
# 4. Spina bifida occulta
#
# Answer:
# 1
# A lateral sliding flap done on a tooth with roots denuded for 6 years will show
# choose only one of the following options:
# 1. PDL fibres attached to cementum
# 2. PDL fibres attached to dentin
# 3. Epithelium adjacent to previously denuded root surface
# 4. Co adaptation to the remaining fibres
#
# Answer: 3
# Cystinuria is characterised by –
# choose only one of the following options:
# 1. Generalised aminoaciduria
# 2. Systemic acidosis
# 3. Deposition of cystine crystals in Renal tubular cells
# 4. Recurrent urinary caliculi
#
# Answer: 3
# Child of Vasanthi was weaned from breast milk on the 5th day and was given sugarcane juice the child developed hypoglycemia and hepatomegaly biochemical examination showed hypophosphatemia and enzyme deficiencies–reducing substances in urine. The child is probably suffering from which of the following enzyme deficiencies –
# choose only one of the following options:
# 1. Fructokinase
# 2. Aldolase B
# 3. Glucose 6 Phosphatase
# 4. Beta galactosidase
#
# Answer: 3
# A Middle aged woman presents with fissures in mouth, tingling sensation and peripheral neuropathy. Investigations showed reduced glutathione reductase activity. which vitamin deficiency is the likely cause of this?
# choose only one of the following options:
# 1. Vitamin B1
# 2. Vitamin 82
# 3. Vitamin 86
# 4. Vitamin B l2
#
# Answer:
#
# Which of the following leads to an increase in enzyme activity -
# choose only one of the following options:
# 1. Increase in temperature
# 2. Decrease in activation energy
# 3. Extremes of pH value
# 4. Low substrate concentration
#
# Answer: 1
# A radiograph is shown below. This type of root morphology has highest incidence in which population?
# choose only one of the following options:
# 1. African
# 2. Caucasians
# 3. Mongoloids
# 4. Asians
#
# Answer:
# 1
# Which of the following marked muscles is Involved in Opening of jaw?
# choose only one of the following options:
# 1. A
# 2. B
# 3. C
# 4. D
#
# Answer: 1
# Light transmitting wedges transmit:
# choose only one of the following options:
# 1. 70-80% of incident light
# 2. 80-85% of incident light
# 3. 85-90% of incident light
# 4. 90-95% of incident light
#
# Answer: 1
# Which of the following is considered as high risk infant?
# choose only one of the following options:
# 1. Working mother
# 2. Antenatal preeclampsia
# 3. Third child
# 4. Twins
# Answer:
# 2.
# Mantle cell Carcinoma shows
# choose only one of the following options:
# 1. CD 5+, CD 25-
# 2. CD 5+, CD 10+
# 3. CD 5+, CD 23+
# 4. CD 5+, CD 23-
#
# Answer: 1
# Which of the following impression material requires a hardener?
# choose only one of the following options:
# 1. Agar
# 2. Alginate
# 3. Elastomers
# 4. Impression compound
# Answer: 3.
# The force applied to cause root movement should be
# choose only one of the following options:
# 1. Positive intermittent force
# 2. Torque or moment
# 3. Extra - oral
# 4. Gentle action
#
# Answer: 1
# Reversal lines are characteristic on the radiograph of:
# choose only one of the following options:
# 1. Osteoma
# 2. Osteosarcoma
# 3. Epidermoid cyst
# 4. Paget's disease of bone
#
# Answer: None of
# In resorption of roots of the primary teeth, the
# dental pulp
# choose only one of the following options:
# 1. Plays a passive role
# 2. Becomes a fibrotic non—vital mass
# 3. Initiates resorption from the inner surface of roots
# 4. Aids in formation of secondary dentin slowing down resorption
#
# Answer: 1
# Unattached gingiva:
# choose only one of the following options:
# 1. Is interdental gingiva
# 2. Is below mucogingival fold
# 3. c)	Cannot be separated by probe
# 4. d)	Is marginal gingiva
#
# Answer: c)
# Which one of the following is the most common tumor associated with type I neurofibromatosis –
# choose only one of the following options:
# 1. Optic nerve glioma
# 2. Meningioma
# 3. Acoustic schwannoma
# 4. Low grade astrocytoma
#
# Answer: 1
# The facial proportions  between upper, middle and lower thirds of fare Is:
# choose only one of the following options:
# 1. 25:50:25
# 2. 34:33:33
# 3. 35:30:35
# 4. 30:35:35
#
# Answer: 1
# Chicken pox infection in mother most dangerous for the baby when it occurs at -
# choose only one of the following options:
# 1. 14-28 weeks
# 2. 3 -9 weeks
# 3. 28-37weeks
# 4. 8-14weeks
# Answer: The most dangerous
# Which of the following is activated by intrinsic or extrinsic pathway's?
# choose only one of the following options:
# 1. Necroptosis
# 2. Apoptosis
# 3. Necrosis
# 4. Pyroptosis
#
# Answer: Nec
# Swelling and redness of the orifices of minor salivary glands of the palate occurs in:
# choose only one of the following options:
# 1. Nicotinic stornatitis
# 2. Leukoplakia
# 3. Fovea palatine
# 4. Erythroplakia
#
# Answer: ery
# A 10-year old boy was presented with a mass in abdomen. On imaging, the para-aoic lymph nodes were enlarged. On biopsy, starry sky appearance was seen. What is the underlying abnormality?
# choose only one of the following options:
# 1. p53 gene mutation
# 2. Rb gene mutation
# 3. Translocation involving BCR-ABL gene
# 4. Translocation involving Myc gene
#
# Answer: 1
# Mosaic pattern of bone is seen in radiographic features of:
# choose only one of the following options:
# 1. Fibrous dysplasia
# 2. Paget's disease
# 3. Osteopetrosis
# 4. Osteogenesis imperfecta
#
# Answer: Oste
# Regeneration leads to formation of which layer of cementum:
# choose only one of the following options:
# 1. Cellular mixed cementum
# 2. Cellular intrinsic fibre cementum
# 3. Acellular extrinsic fiber cementum
# 4. Acellular afibrillar cementum
#
# Answer: 3
# C wave in JVP due to
# choose only one of the following options:
# 1. Atrial contraction
# 2. Atrial filling
# 3. Tricuspid bulging
# 4. Rapid ventricular filling
#
# Answer: 3
# Cherry red spot after trauma is seen in children due to:
# choose only one of the following options:
# 1. CRAO
# 2. CRVO
# 3. Berlin's edema
# 4. Niemann-Pick's disease
#
# Answer: 1
# The one measurement of fetal maturity that is not affected by a 'bloody tap' during amniocentesis is:
# choose only one of the following options:
# 1. L/S ratio
# 2. Phosphatidyl glycerol
# 3. α-fetoprotein
# 4. Bilirubin as a measured by DOD 450
#
# Answer: 3
# A 25 year old lady on treatment for rheumatoid ahritis has following lab findings: Hb-9gm/dl, MCV- 55fl, serum iron-30microgm/d1, ferritin 200 ng/ml, TIBC- 298 micrograms/dl. What is the most probable diagnosis?
# choose only one of the following options:
# 1. Thalassemia minor
# 2. Thalassemia major
# 3. Anemia of chronic disease
# 4. Iron deficiency anemia
#
# Based on the given lab
# A 22 years old male presented with history of fever, sore throat and enlarged neck lymph nodes. He was ordered a Paul-Bunnell test with a suspicion of Infectious mononucleosis. What is the immunological basis behind the use of this test?
# choose only one of the following options:
# 1. Heterophile antibody test
# 2. Complement mediated agglutination reaction
# 3. Homophile antibody test
# 4. Latex agglutination test
#
# Answer: 1
# In the management of anaphylaxis, which action of adrenaline is not observed?
# choose only one of the following options:
# 1. Bronchodilation by beta-receptors
# 2. Cardiovascular effects of beta-receptors
# 3. Action on blood vessels by alpha-receptors
# 4. Action on presynaptic alpha-receptors to release histamine
#
# An
# A 24 years old college student while playing hockey injured his right knee. This patient presents after 3 months with instability of knee joint in it full extension without instability at 90 degree of flexion. The structure most commonly damaged is:
# choose only one of the following options:
# 1. Posterolatilal pa of anterior cruciate ligament
# 2. Anteromedial pa of anterior cruciate ligament
# 3. Posterior cruciate ligament
# 4. Anterior hom of medial meniscus
#
# Answer: 1
# Which of the following is the diluting segment of kidney?
# choose only one of the following options:
# 1. PCT
# 2. Collecting duct
# 3. Ascending thick loop Henle
# 4. Descending loop of Henle
#
# Answer: 1
# Mandibular molars show how many patterns of Accessory Canals
# choose only one of the following options:
# 1. 1
# 2. 2
# 3. 3
# 4. 4
# Answer: 3
#
# Which of the following sites is least commonly preferred for insulin injection?
# choose only one of the following options:
# 1. Anterior thigh
# 2. Lateral thigh
# 3. Dorsum of arm
# 4. Around umbilicus
# Answer:
# 4.
# A diabetic patient presented with uncontrolled blood sugar level. He has history of pancreatitis and family history of urinary bladder carcinoma. He does not want to take injectable drugs. Which of the following drug can be added to control his blood sugar?
# choose only one of the following options:
# 1. Liraglutide
# 2. Sitagliptin
# 3. Canagliflozin
# 4. Pioglitazone
# Answer: 1.
# DNA Methylation is not related with?
# choose only one of the following options:
# 1. Mismatch repair
# 2. DNA Replication
# 3. Gene silencing
# 4. Capping of mRNA
#
# An
# Optic atrophy is not seen in:
# choose only one of the following options:
# 1. Retinitis pigmentosa
# 2. Methanol poisoning
# 3. Central retinal aerial occlusion (CRAO)
# 4. Polypoidal choroidal vasculopathy
#
# Answer:
#
# The patient suffered from hypogonadism, failure to thrive, loss of taste and unable to maintain stability. This shows the deficiency of:
# choose only one of the following options:
# 1. Zinc
# 2. Chromium
# 3. Copper
# 4. Potassium
# Answer: 1.
# A-alpha ﬁbers have a speed of conduction of  ------ m/s.
# choose only one of the following options:
# 1. 20-Oct
# 2. 40-50
# 3. 50-70
# 4. 70-120
#
# Answer: 3
# Advantage of the submarginal falp for periradicular surgery is?
# choose only one of the following options:
# 1. Crestal bone less
# 2. Bleeding lees
# 3. Gingival shrinking less
# 4. Flap closure easyer
#
# Answer:
# Fine needle aspiration cytology (FNAC) is not enough to diagnose:
# choose only one of the following options:
# 1. Papillary carcinoma of thyroid
# 2. Follicular carcinoma of thyroid
# 3. Carcinoma breast
# 4. Adenocarcinoma lung
#
# Answer:
#
# MHC antigens are absent on?
# choose only one of the following options:
# 1. Platelet
# 2. Erythrocyte
# 3. Neutrophil
# 4. Monocyte
#
# Answer: 1
# Infarction of anterior inferior cerebellar artery may cause damage to
# choose only one of the following options:
# 1. Pyramidal tract
# 2. Lateral spinothalamic tract
# 3. Vestibular nuclei
# 4. Spinal nucleus of trigeminal nerve
#
# Answer: 2
# Clavulanic acid added to ampicillin causes:
# choose only one of the following options:
# 1. Increase	effectivity	against	gram-negative organisms
# 2. Inhibition of β-lactamases
# 3. Increases the effectiveness against delta lactamase producing organism
# 4. Increase	effectivity	against	gram-positive organisms
#
# Answer: 2
# Which of the following disease cause damage of vertebral body & intervertebral space?
# choose only one of the following options:
# 1. Tuberculosis
# 2. Multiple myeloma
# 3. Lymphoma
# 4. Metastasis
#
# Answer: 3
# A woman comes with postdated pregnancy at 42 weeks. The initial evaluation would be:
# choose only one of the following options:
# 1. Induction of labour
# 2. Review of previous menstrual history
# 3. Cesarean section
# 4. USG to confirm fetal viability
#
# Which of the following is the most appropriate method for obtaining a urine specimen for culture in an 8 month old girl –
# choose only one of the following options:
# 1. Suprapubic aspiration
# 2. Indwelling catheter sample
# 3. Clean catch void
# 4. Urinary bag sample
#
# Answer:
# 3
# It is likely that cell mediated immune reactions (delayed
# hypersensitivity) occur in periodontitis because subjects with periodontitis have
# choose only one of the following options:
# 1. High levels of histamine in involved gingival tissue
# 2. IgG antibodies reactive with plaque bacterial antigens
# 3. Ttymphocytes sensitized to bacterial plaque antigens
# 4. High Levels of collagenase in gingival fluids
#
# Answer: 3
# Which of the following disorder of mother leads to microcephaly in baby –a)  SLEb)  Hepatitis A c) Phenylketonuriad)  Rubella
# choose only one of the following options:
# 1. ab
# 2. cd
# 3. bd
# 4. ac
#
# Answer: ab (
# Changes seen in conjunctiva after vitamti. A deficiency:
# choose only one of the following options:
# 1. Actinic degeneration
# 2. Hyperplasia of goblet cells
# 3. Hyperkeratosis of squamous epithelium
# 4. Stromal infiltration with lymphocytes
#
# Percentage of lactose in human milk is –
# choose only one of the following options:
# 1. 7.2gm
# 2. 4.5gm
# 3. 8.0gm
# 4. 6.7gm
# Answer: 3.
# A 4 yr old girl child suffering from vomiting, cerebral edema and is being treated for viral infection from past 5 days. Liver biopsy in this patient may show
# choose only one of the following options:
# 1. Central haemorrhagic necrosis
# 2. Non-alcoholic steatohepatitis
# 3. Autoimmune hepatitis
# 4. Microvesicular steatohepatitis
#
# Answer: The given
# Preferred drug for the treatment of uncomplicated grade 2 hypeension in a 48 year old man is
# choose only one of the following options:
# 1. Chlohalidone
# 2. Triamterene
# 3. Spironolactone
# 4. Furosemide
#
# Answer: 1
# Mid palatal split following Le-Fort 1 osteotomy is done by moving the maxilla in which direction?
# choose only one of the following options:
# 1. Superior
# 2. Inferior
# 3. Antero-posterior
# 4. Transverse
#
# Answer: Anter
# In a patient with heart disease, which of the following should not be used to control PPH:
# choose only one of the following options:
# 1. Methylergometrine
# 2. Oxytocin
# 3. Misoprostol
# 4. Carboprost
#
# Answer: 1
# What is the codon for selenocysteine?
# choose only one of the following options:
# 1. UAG
# 2. UGA
# 3. UAA
# 4. GUA
#
# The codon for sel
# FNAC can not diagnose
# choose only one of the following options:
# 1. Papillary carcinoma of thyroid
# 2. Follicular carcinoma of thyroid
# 3. Anaplastic carcinoma of thyroid
# 4. Medullary carcinoma of thyroid
# 5. Lymphoma
# Endotoxin of gram -ve bacteria that do not cause pathogenesis of natural disease
# choose only one of the following options:
# 1. Mycobacterium
# 2. Klebsiella
# 3. Vibrio
# 4. E.coli
#
# The correct answer is:
# Transmits which disease
# choose only one of the following options:
# 1. Kyasanur forest disease
# 2. Scrub typhus
# 3. Japanese encephalitis
# 4. Leptospirosis
# Answer: 1.
# Liver is divided into eight segments according to Couinaud's classification based upon
# choose only one of the following options:
# 1. Bile Duct
# 2. Poal vein
# 3. Hepatic Vein
# 4. Hepatic aery
#
# The liver is divided into
# Which of the following drugs acting on dilator pupillae has an action analogous to that of pilocarpine on sphincter papillae?
# choose only one of the following options:
# 1. Timolol
# 2. Epinephrine
# 3. Neostigmine
# 4. Tropicamide
#
# Answer: 1

# %%
df["cop"][3]
# Out:
# 3

# %%
df['prediction'] = None

for index, row in df.iterrows():
    pom = row["answer"].split("\n")[-1]
    if row["opa"] in pom or "1." in pom or "1" in pom:
        df.at[index, "prediction"] = 0
    elif row["opb"] in pom or "2." in pom or "2" in pom:  
        df.at[index, "prediction"] = 1
    elif row["opc"] in pom or "3." in pom or "3" in pom:
        df.at[index, "prediction"] = 2
    elif row["opd"] in pom or "4." in pom or "4" in pom:  
        df.at[index, "prediction"] = 3
    else:
        df.at[index, "prediction"] = "invalid"
        print("Invalid detected: ", pom, index)
# Out:
# Invalid detected:  Answer: Arth 3
# Invalid detected:  5. Due to loss of 7
# Invalid detected:  The heart of a controlled 8
# Invalid detected:  Answer: I. 10
# Invalid detected:  Answer 14
# Invalid detected:  Answer: The easiest 18
# Invalid detected:  Answer: 8 20
# Invalid detected:   21
# Invalid detected:   25
# Invalid detected:  Answer: Triiodothy 27
# Invalid detected:  Answer: None of 29
# Invalid detected:   30
# Invalid detected:  T-lymph 31
# Invalid detected:  Answer: Mean and 32
# Invalid detected:  Answer: Prever 34
# Invalid detected:  Answer: Interglob 35
# Invalid detected:   36
# Invalid detected:  Answer:  37
# Invalid detected:  Answer: None of 39
# Invalid detected:  5. Show a high wear 45
# Invalid detected:  Answer: Lower  48
# Invalid detected:   51
# Invalid detected:  Answer 53
# Invalid detected:  Arg 57
# Invalid detected:  Answer: Thym 58
# Invalid detected:  The under-5 mort 59
# Invalid detected:  The correct answer is: 61
# Invalid detected:  Answer: The correct 63
# Invalid detected:  The most likely cause is 66
# Invalid detected:  Based 67
# Invalid detected:  The 73
# Invalid detected:  The possible explanation for a 76
# Invalid detected:  Correct answer 77
# Invalid detected:  Answer: Chyl 79
# Invalid detected:  Based 81
# Invalid detected:  Answer: Dentin 87
# Invalid detected:   88
# Invalid detected:  Answer 91
# Invalid detected:  Answer: None of 92
# Invalid detected:  Answer: All of the 93
# Invalid detected:  Polym 94
# Invalid detected:  Answer: The recommended daily 98
# Invalid detected:  Answer: Tand 101
# Invalid detected:   104
# Invalid detected:  Answer: Mandib 105
# Invalid detected:  An 110
# Invalid detected:  The natural disaster causing the 115
# Invalid detected:  An 116
# Invalid detected:  The 118
# Invalid detected:  5. Plaque index ( 119
# Invalid detected:  Answer: 122
# Invalid detected:  An 123
# Invalid detected:  Answer: None of 125
# Invalid detected:  The most likely diagnosis is 126
# Invalid detected:  Answer:  129
# Invalid detected:  Answer: Multiple 133
# Invalid detected:   138
# Invalid detected:  Answer: 142
# Invalid detected:   145
# Invalid detected:  None of 167
# Invalid detected:  Answer: None of 170
# Invalid detected:  Correct answer: Tro 172
# Invalid detected:  Answer: Calci 178
# Invalid detected:  Answer: 181
# Invalid detected:  Answer: The best 183
# Invalid detected:  Answer: The l 184
# Invalid detected:  The most likely diagnosis based 191
# Invalid detected:  To find the steady state 194
# Invalid detected:  The 195
# Invalid detected:  5. Creating supportive environments 200
# Invalid detected:  Answer: The diameter of 201
# Invalid detected:  The symptoms described in the 202
# Invalid detected:  Based on the information provided 210
# Invalid detected:  Answer: None of 211
# Invalid detected:   212
# Invalid detected:  Answer: None of 216
# Invalid detected:  Answer: The least 218
# Invalid detected:  To calculate the sample size 222
# Invalid detected:  An 226
# Invalid detected:  Answer: The most 232
# Invalid detected:   235
# Invalid detected:  The compartment of the 238
# Invalid detected:  Based on the information provided 241
# Invalid detected:  Answer: None of the 243
# Invalid detected:  Correct answer:  246
# Invalid detected:  5. Congenital ins 250
# Invalid detected:   252
# Invalid detected:   260
# Invalid detected:   261
# Invalid detected:  Answer: None of 262
# Invalid detected:  Answer: The most 263
# Invalid detected:  All 264
# Invalid detected:  Answer: None of 265
# Invalid detected:  Answer 268
# Invalid detected:   269
# Invalid detected:  Answer: William 274
# Invalid detected:   277
# Invalid detected:  Answer:  279
# Invalid detected:  Answer: None of 280
# Invalid detected:   281
# Invalid detected:  Correct answer:  282
# Invalid detected:  5. Well-circum 283
# Invalid detected:  Answer: The main 285
# Invalid detected:  The best for determining the 286
# Invalid detected:  The organism is likely 288
# Invalid detected:  Answer: None of 289
# Invalid detected:  Answer: All of 290
# Invalid detected:  Answer: The z 291
# Invalid detected:   292
# Invalid detected:  Answer: Myoc 294
# Invalid detected:  Answer: Increase 295
# Invalid detected:   296
# Invalid detected:  5. Mandibular can 300
# Invalid detected:  Answer: Fib 301
# Invalid detected:  The 302
# Invalid detected:  Answer: Diarr 303
# Invalid detected:   305
# Invalid detected:  Answer 309
# Invalid detected:  Answer 310
# Invalid detected:  The 314
# Invalid detected:  Answer: Ethambut 319
# Invalid detected:  Answer 325
# Invalid detected:  Answer 326
# Invalid detected:  Answer 327
# Invalid detected:  Answer:  331
# Invalid detected:  Answer: The least 337
# Invalid detected:  Answer: The question 340
# Invalid detected:   342
# Invalid detected:   343
# Invalid detected:  Answer: The body repl 347
# Invalid detected:  An 348
# Invalid detected:  To calculate the infant mort 351
# Invalid detected:  Answer: C, 352
# Invalid detected:  The symptoms described in the 353
# Invalid detected:  Answer: None of 354
# Invalid detected:  5. Sensitivity  364
# Invalid detected:  A longitudinal study 368
# Invalid detected:  Answer: The useful 374
# Invalid detected:  Answer: The front 378
# Invalid detected:  The best treatment for a 380
# Invalid detected:  Answer: None of 383
# Invalid detected:  The correct answer is: 384
# Invalid detected:  5. Neonatal hem 385
# Invalid detected:  Answer 390
# Invalid detected:  Answer: The number 391
# Invalid detected:   393
# Invalid detected:  Answer:  394
# Invalid detected:  Answer: 396
# Invalid detected:  Answer: The correct answer 397
# Invalid detected:   400
# Invalid detected:  Correct answer:  406
# Invalid detected:  The most likely diagnosis is 407
# Invalid detected:  Answer 410
# Invalid detected:  Answer: a) 411
# Invalid detected:  Answer: The focal 413
# Invalid detected:   416
# Invalid detected:  Answer: 421
# Invalid detected:  The 423
# Invalid detected:  Answer: None of 425
# Invalid detected:  Answer: 433
# Invalid detected:  Based 434
# Invalid detected:   443
# Invalid detected:  Answer: None of 452
# Invalid detected:  Answer: c) 454
# Invalid detected:  Answer: The most dangerous 457
# Invalid detected:  Answer: Nec 458
# Invalid detected:  Answer: ery 459
# Invalid detected:  Answer: Oste 461
# Invalid detected:  Based on the given lab 466
# Invalid detected:  An 468
# Invalid detected:   471
# Invalid detected:  An 474
# Invalid detected:   475
# Invalid detected:  Answer:  478
# Invalid detected:   479
# Invalid detected:   484
# Invalid detected:   488
# Invalid detected:  Answer: The given 490
# Invalid detected:  Answer: Anter 492
# Invalid detected:  The codon for sel 494
# Invalid detected:  5. Lymphoma 495
# Invalid detected:  The correct answer is: 496
# Invalid detected:  The liver is divided into 498

# %%
sum(df["cop"] == df["prediction"])
# Out:
# 142

# %%
sum(df["cop"] != df["prediction"])
# Out:
# 358

# %%
accuracy = sum(df["cop"] == df["prediction"])/df.shape[0]
false_positive = sum(df["cop"] != df["prediction"])/df.shape[0]
no_invalid = sum(df["prediction"] == "invalid")/df.shape[0]

print("Accuracy: ", accuracy)
print("False positive: ", false_positive)
print("Invalid: ", no_invalid)
# Out:
# Accuracy:  0.292
# False positive:  0.708
# Invalid:  0.366

# %%
accuracy = sum(df["cop"] == df["prediction"])/df.shape[0]
false_positive = sum(df["cop"] != df["prediction"])/df.shape[0]

print("Accuracy: ", accuracy)
print("False positive: ", false_positive)
# Out:
# Accuracy:  0.284
# False positive:  0.716

# %%
# Out:
#                                      id  \
# 0  84f328d3-fca4-422d-8fb2-19d55eb31503
# 2  f6ce5597-c646-4a2b-8767-764f185be603
# 3  21fe4c49-f0cd-4c31-8eec-3966bbfb963e
# 6  94492b8f-7c4d-4b43-ae93-90b0a49170b3
# 7  f2b6b487-dc9b-47b7-ab30-7bce3db954cb
#
#                                             question               opa  \
# 0  Which of the following is derived from fibrobl...            TGF-13
# 2  Which macrolide is active against Mycobaterium...      Azithromycin
# 3     Xanthenuric acid is produced in metabolism of?          Tyrosine
# 6                   Marker of endoplasmic reticulum?  Acid phosphatase
# 7  A 10 years old male presents a smooth swelling...   Inguinal hernia
#
#                      opb                             opc           opd  cop  \
# 0                   MMP2                        Collagen  Angiopoietin   -1
# 2          Roxithromycin                  Clarithromycin    Framycetin   -1
# 3                Glycine                      Methionine    Tryptophan   -1
# 6  Glucose-6-phosphatase                        Catalase           LDH   -1
# 7   Congenital hydrocele  Encysted hydrocele of the cord    Varicocele   -1
#
#   choice_type exp  subject_name topic_name promt
# 0      single         Pathology       None  None
# 2      single      Pharmacology       None  None
# 3      single           Unknown       None  None
# 6      single        Physiology       None  None
# 7      single           Surgery       None  None

# %%
# Out:
# Which of the following is derived from fibroblast cells ?
# choose only one of the following options:
# a. TGF-13
# b. MMP2
# c. Collagen
# d. Angiopoietin

# %%
# Out:
# 49608
